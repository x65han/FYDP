# %%
import os
import random

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import tensorflow as tf
import tensorboard

tf_config = tf.ConfigProto()
tf_config.gpu_options.allow_growth = True
sess = tf.Session(config=tf_config)

import pandas as pd
import utils
from model_config import config
from vae import VAEModel
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize

random.seed = 46
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# Get Michael's data
raw_file = []
with open("caption_for_vae.txt", "r") as f:
    for x in f:
        raw_file.append(x)
        
lyrics = []
for content in raw_file:
    if content[0] != "[":
        content = content.replace(' \n', '\n')
        lyrics.append(content)

random.shuffle(lyrics)
len(lyrics)
# Out:
# 284809

# %%
# Get a list of sentences [sentence 1 \n, sentence2....]
# lyrics = utils.get_sentences(file_path = 'data/7-selected-no-labels.txt')

print('[INFO] Number of sentences in Lyrics = {}'.format(len(lyrics)))

df = pd.DataFrame(lyrics, columns=['sentence'])
df['label'] = 0

sentences = []
for sent in df['sentence']:
    sentences.append(utils.clean_sentence(sent))   # clean_sentence: regex to make lower case; num--><NUM> token

df['sentence'] = sentences
df = df.sample(frac=1).reset_index(drop=True)    # for visuliaztion purpose
df.head(15)
# Out:
# [INFO] Number of sentences in Lyrics = 284809
#                                              sentence  label
# 0   a pink framed bicycle resting against an arcad...      0
# 1   birds fly close to the ground where a sheep is...      0
# 2         a group of people getting on a small plane.      0
# 3   wooden train passing through a forested hilly ...      0
# 4   three statues positioned near a fountain in a ...      0
# 5   a neatly decorated room with a piano and suspe...      0
# 6           a large cheese pizza with a meat topping.      0
# 7   several boats docked on the shore near a mount...      0
# 8     a surfer riding a large wave on his surf board.      0
# 9   a group of people with uniforms playing with a...      0
# 10   a bowl filled with , fruit, crackers and greens.      0
# 11  a man riding a snowboard down a snow covered s...      0
# 12  a bowl containing broccoli and pasta sit on a ...      0
# 13  a black and white clock some paintings and a w...      0
# 14            a man is teaching a small child to ski.      0

# %%
print('[INFO] Tokenizing input and output sequences')
filters = '!"#$%&()*+/:;<=>@[\\]^`{|}~\t\n'
labels = list(df['label'])


# output x is a list of indices. word2index produced by nltk tokenizer
x, word_index = utils.tokenize_sequence(sentences,
                                             filters,
                                             config['num_tokens'],
                                             config['vocab_size'])

print('[INFO] Split data into train-validation-test sets')
x_train, _x_val_test, train_labels, _val_test_labels = train_test_split(x, labels, test_size = 0.1, random_state = 10)
x_val, x_test, val_labels, test_labels = train_test_split(_x_val_test, _val_test_labels, test_size = 0.5, random_state = 10)

# this will use the pre-trained emb from other tasks
if config['use_pre_trained']:
    w2v = config['pre_trained_path']
# this will use amazon word emb
else:
    w2v = config['w2v_file']

'''
embedding_matrix is originally a list of np.random.uniform(-0.05, 0.05, size=(len(word_index), embedding_dim))
And then for each word we get 
            embeddings_vector = w2v_model[word]
            embeddings_matrix[i] = embeddings_vector
This might not be useful for music embedding training. But the initialize process does.
'''    
embeddings_matrix = utils.create_embedding_matrix(word_index,
                                                  config['embedding_size'],
                                                  w2v)

# Re-calculate the vocab size based on the word_idx dictionary
config['vocab_size'] = len(word_index)
# Out:
# [INFO] Tokenizing input and output sequences
# [INFO] Split data into train-validation-test sets

# %%
model = VAEModel(config, 
                 embeddings_matrix,
                 word_index)
# Out:
# [INFO] Building Model ...

# %%
model.train(x_train, x_val)
# Out:
# [INFO] Training process started
# Epoch   1/50 - Time  485.2 BLEU: 62.35 | 46.15 | 36.1 | 28.29
# Epoch   2/50 - Time  490.0 BLEU: 47.13 | 29.03 | 19.59 | 13.39
# Epoch   3/50 - Time  491.0 BLEU: 48.24 | 30.3 | 20.82 | 14.43
# Epoch   4/50 - Time  491.6 BLEU: 49.06 | 31.4 | 21.77 | 15.2
# Epoch   5/50 - Time  492.4 BLEU: 50.18 | 32.42 | 22.75 | 16.1
# Epoch   6/50 - Time  492.2 BLEU: 51.37 | 33.51 | 23.63 | 16.74
# Epoch   7/50 - Time  492.9 BLEU: 52.18 | 34.52 | 24.66 | 17.68
# Epoch   8/50 - Time  493.2 BLEU: 52.59 | 35.22 | 25.27 | 18.19
# Epoch   9/50 - Time  493.3 BLEU: 53.49 | 36.17 | 26.2 | 18.96
# Epoch  10/50 - Time  493.8 BLEU: 54.05 | 36.85 | 26.88 | 19.68
# Epoch  11/50 - Time  494.2 BLEU: 54.26 | 37.17 | 27.21 | 19.95
# Epoch  12/50 - Time  494.5 BLEU: 54.63 | 37.77 | 27.91 | 20.65
# Epoch  13/50 - Time  494.4 BLEU: 54.66 | 38.01 | 28.16 | 20.85
# Epoch  14/50 - Time  495.4 BLEU: 54.9 | 38.11 | 28.22 | 20.91
# Epoch  15/50 - Time  494.9 BLEU: 54.67 | 37.65 | 27.73 | 20.44
# Epoch  16/50 - Time  496.2 BLEU: 55.09 | 38.57 | 28.76 | 21.47
# Epoch  17/50 - Time  495.3 BLEU: 55.03 | 38.42 | 28.66 | 21.39
# Epoch  18/50 - Time  495.9 BLEU: 54.41 | 37.64 | 27.77 | 20.52
# Epoch  19/50 - Time  496.4 BLEU: 54.75 | 38.23 | 28.42 | 21.15
# Epoch  20/50 - Time  495.8 BLEU: 54.67 | 38.05 | 28.32 | 21.11
# Epoch  21/50 - Time  496.8 BLEU: 55.42 | 38.71 | 28.86 | 21.48
# Epoch  22/50 - Time  497.6 BLEU: 54.9 | 38.35 | 28.56 | 21.24
# Epoch  23/50 - Time  497.6 BLEU: 55.19 | 38.72 | 28.97 | 21.67
# Epoch  24/50 - Time  498.3 BLEU: 54.75 | 38.22 | 28.45 | 21.14
# Epoch  25/50 - Time  497.6 BLEU: 55.11 | 38.66 | 28.89 | 21.62
# Epoch  26/50 - Time  497.9 BLEU: 54.85 | 38.6 | 28.98 | 21.78
# Epoch  27/50 - Time  499.5 BLEU: 55.13 | 38.5 | 28.61 | 21.26
# Epoch  28/50 - Time  498.7 BLEU: 55.67 | 39.32 | 29.54 | 22.23
# Epoch  29/50 - Time  499.8 BLEU: 55.33 | 39.07 | 29.46 | 22.19
# Epoch  30/50 - Time  499.4 BLEU: 55.79 | 39.51 | 29.76 | 22.42
# Epoch  31/50 - Time  498.7 BLEU: 55.19 | 38.85 | 29.13 | 21.84
# Epoch  32/50 - Time  500.8 BLEU: 54.75 | 38.5 | 28.9 | 21.68
# Epoch  33/50 - Time  500.0 BLEU: 54.91 | 38.67 | 29.06 | 21.88
# Epoch  34/50 - Time  501.0 BLEU: 55.44 | 39.38 | 29.79 | 22.54
# Epoch  35/50 - Time  500.8 BLEU: 55.02 | 39.07 | 29.49 | 22.25
# Epoch  36/50 - Time  501.2 BLEU: 55.34 | 39.35 | 29.78 | 22.5
# Epoch  37/50 - Time  501.8 BLEU: 55.71 | 39.71 | 30.1 | 22.79
# Epoch  38/50 - Time  501.4 BLEU: 55.56 | 39.35 | 29.66 | 22.31
# Epoch  39/50 - Time  502.7 BLEU: 55.8 | 39.81 | 30.15 | 22.8
# Epoch  40/50 - Time  502.7 BLEU: 55.76 | 39.46 | 29.75 | 22.43
# Epoch  41/50 - Time  504.0 BLEU: 55.19 | 39.0 | 29.38 | 22.11
# Epoch  42/50 - Time  503.7 BLEU: 55.72 | 39.72 | 30.06 | 22.7
# Epoch  43/50 - Time  503.4 BLEU: 55.36 | 39.36 | 29.79 | 22.52
# Epoch  44/50 - Time  503.4 BLEU: 55.1 | 39.01 | 29.44 | 22.22
# Epoch  45/50 - Time  504.2 BLEU: 55.65 | 39.67 | 29.93 | 22.56
# Epoch  46/50 - Time  504.2 BLEU: 55.23 | 39.29 | 29.69 | 22.45
# Epoch  47/50 - Time  504.9 BLEU: 55.78 | 39.8 | 30.18 | 22.89
# Epoch  48/50 - Time  504.0 BLEU: 55.52 | 39.46 | 29.85 | 22.58
# Epoch  49/50 - Time  504.9 BLEU: 55.22 | 39.41 | 29.84 | 22.55
# Epoch  50/50 - Time  505.5 BLEU: 55.56 | 39.42 | 29.78 | 22.49

# %% [markdown]
# ### Notes
# - Using embeddings pre-trained on other corpus gives lower BLEU
# - Using embeddings trainable=True is not very useful
# - No effect (total loss still keeps increasing after 1500 iters) on removing/changing lstm dropout
# - After 2500 iterations, KL loss starts dipping
# - After 1500 iterations, total loss starts to increase
# - Tried a different kl weight anneal schedule<br>
# <code>from scipy.stats import logistic<br>
# logistic.cdf(iter_i/4500) - 0.5</code><br>
# Doesn't work since the annealing has to be done very very slowly

# %%
config['load_checkpoint'] = 50

# %%
if config['load_checkpoint'] != 0: 
    checkpoint = config['model_checkpoint_dir'] + str(config['load_checkpoint']) + '.ckpt'
else:
    checkpoint = tf.train.get_checkpoint_state(os.path.dirname('models/checkpoint')).model_checkpoint_path
    
preds = model.predict(checkpoint, x_test)
# Out:
# INFO:tensorflow:Restoring parameters from models/lyrics-50.ckpt
# BLEU 1 to 4 : 53.29 | 36.54 | 27.08 | 20.13

# %%
# WHAT'S THIS
model.get_diversity_metrics(checkpoint, x_test[:1000], num_samples=10, num_iterations=1)

# %%
lb = 51
ub = 100
# count = 50
model.show_output_sentences(preds[lb:ub], 
                            x_test[lb:ub], 
                            )
# Out:
# A: a group of sheep in a field with a fence in the background .
# G: a group of cows in a field with a hand in the traffic
#
# A: a small baby sleeping on a few blankets ,
# G: a small dog laying on a bed with spectators
#
# A: a fishtank sitting above a toilet bowl in a bathroom
# G: a cat sitting in a bathroom sink in a bathroom
#
# A: a person sitting behind a table with a teddy bear , cellphone and a couple
# G: a little boy sitting in a desk with a bear computer and a bear .
#
# A: round pizza on a black and white checkered tablecloth
# G: a pizza sitting on a table near green bananas
#
# A: a man is falling on his back while snowboarding .
# G: a man is looking at the beach with sheep .
#
# A: two guys are outside moving a refrigerator
# G: person luggage bags are sitting on a table
#
# A: four men stand behind a couch playing a video game .
# G: two men playing a game of food inside a kitchen .
#
# A: a black and white cat a chair and some bicycles
# G: a black and white cat in a car and chair
#
# A: in rail station a clock hangs near the top with glass around .
# G: a clock in the middle of a building with wedding on it .
#
# A: a dog with a vest is riding a skateboard .
# G: a man in a car is riding a motorcycle .
#
# A: a man standing in a building with a stuffed animal
# G: a man standing in a car with a brown horse
#
# A: a double image of a tennis player retrieving a ball and spectators watching intently .
# G: a tennis player hitting a ball , a tennis player , and the ball .
#
# A: a red brick wall with a garage door that has a barn mural painted on
# G: a white table has been painted on a wooden table with a bunch of items
#
# A: a young boy eating a hot dog covered in onion rings .
# G: a young boy in fur is sitting in his mouth .
#
# A: a man and a woman laying in front of a television .
# G: a man and woman in a bathroom leaning carrying a filled .
#
# A: bathroom basin and mirror in a hotel room
# G: a bathroom with toilet and a shower curtain
#
# A: a young chilc with a white teddy bear on the childs back .
# G: a teddy laptop with a black streets tie on the back .
#
# A: no one can turn down a pizza pie .
# G: a pizza sitting wild a metal box .
#
# A: a group of three officers standing next to each other .
# G: a group of sheep standing next to each other .
#
# A: a black and white photo of school boys wearing ties .
# G: a black and white photo of a man in suit .
#
# A: a blue and yellow train engine sitting on the tracks
# G: a blue and white train sitting outside on the tracks
#
# A: a dog jumping up to catch a pink frisbee
# G: a dog jumping to catch a frisbee frisbee
#
# A: a room with a fridge and an oven and a cooker
# G: a room with a couch , a chair and a window
#
# A: a small boy chewing on a blue and white toy .
# G: a small child holding a large piece of green bananas .
#
# A: two people are standing under a polka dot umbrella .
# G: two people are standing and holding a large airplane .
#
# A: a motorcyclist stops on the road to allow a pedestrian to cross .
# G: a some skiing on the street as a some waiting for plain .
#
# A: a far away bench covers all the distant serenity of a beautiful flower garden .
# G: a wooden table set up with a clock in the traffic shaped .
#
# A: a prop plane parked at an airport with support vehicles around it .
# G: a tennis player jumping in the air with a skateboard at night .
#
# A: to miniature models of a double decker and regular bus .
# G: the skateboarder for the parking lot of people waiting .
#
# A: a man standing by a motor cycle on a street .
# G: a man holding a tennis racket while on a court .
#
# A: a couple of women and a man preparing food in a kitchen .
# G: a couple of women holding a hot dog in a kitchen .
#
# A: a bike sitting in a tub next to a tiled wall
# G: a motorcycle sits in a wooden drinking next to a filled .
#
# A: a man looking at a motorcycle with other motorcycles behind him .
# G: a man in a car with a motorcycle parked by him .
#
# A: some bread rolls butter a plate and cups
# G: woman playing tennis while a game to watch .
#
# A: a picture of a baseball game being played in a stadium .
# G: a enjoying of a bunch of carrots are in a kitchen .
#
# A: two old suitcases sit in the middle of a street .
# G: an old man sits in the front of a truck .
#
# A: a close up of a business truck with writing
# G: a close up of a stop sign with no
#
# A: a person riding a snow board on a snowy slope
# G: a close up of a some skiing on a snowy slope
#
# A: a pristine doctors examining room waiting for the next patient .
# G: a modern kitchen counter made to beverage the kitchen counter .
#
# A: a man in a car holding up a doughnut .
# G: a man in a kitchen next to a woman .
#
# A: a group of people huddled together in a street holding umbrellas
# G: a group of people playing tennis in a field of people
#
# A: the sign is naming the intersection of the streets .
# G: the sign is showing the eat of the intersection .
#
# A: a bride and groom are cutting their cake
# G: a bride and built are cutting their clocks cake
#
# A: two people standing with glasses of wine near a table
# G: a small kid sitting in front of a table
#
# A: street with many signs and two people riding bikes .
# G: people with motorcycles are walking along their street together .
#
# A: car whizzing by with headlights on behind the stop sign
# G: cars parked at a stop sign with a stop sign
#
# A: a group of girls dressed in uniforms with pen writing on their shirts .
# G: a group of people dressed in a black shirt pulling their luggage
#
# A: a fire hydrant on a busy corner surrounded by refuse .
# G: a fire hydrant on a sidewalk with a sidewalk by .

# %%
model.random_sample(checkpoint)
# Out:
# INFO:tensorflow:Restoring parameters from models/lyrics-50.ckpt
# G: a skateboarder hanging on a pole pole at a building .
# G: a man holding a large bird standing over the water .
# G: a passenger train parked with a train in a station .
# G: a prepares in a kitchen with a refrigerator in it .
# G: pizza in a box with a red box and a coffee cup .
# G: a woman sitting on a table with a bag of food .
# G: two women tan face and wearing a tie .
# G: two people holding up a cell phone while in the traffic
# G: a baseball player is in the patterned of a large baseball game .
# G: a man sits on a bench with a colorful frisbee .
# G: a man looking at a camera while holding an umbrella .
# G: a young girl holds a pair of scissors .
# G: a cat is laying with rock on the floor .
# G: a man and woman sitting on top of a table with stuffed animals .
# G: a pair of scissors sits on top of a table
# G: a some riding a skateboard with person luggage bags .
# G: a small bathroom with white touching and toilet seat .
# G: the cow is standing in the grass in the area .
# G: a black laptop in the turned with a red streets is in the traffic .
# G: a small kid sits on a table with a food
# G: two outdoor sitting in a bed near a teddy laptop .
# G: a some is on the skateboard riding his skateboard .
# G: a motorcycle sits on a metal drinking outside .
# G: a banana banana on a table top and the banana .
# G: a man in a black shirt and white shorts playing frisbee over him .
# G: a teddy laptop is on his bed reading on the phone .
# G: a man surfing between two other people .
# G: a some putting into a white toilet in a bathroom area .
# G: a cat is laying on the ground near sheep .
# G: two boats with a large body of water and other buildings .
# G: a bunch of food on a parking lot .
# G: a woman holding skis and a man and skiing .
# G: the man is wearing black shorts is on the beach .
# G: a big building in a city street with buildings
# G: a boy standing over a baseball bat at a baseball game .
# G: small child sleeping on a bench in the rain .
# G: a boy sitting on a bear with his shows top .
# G: a woman and a man in a plane holding up of tennis .
# G: the man is walking down the road against motorcycles .
# G: a man with a large computer in front of a bear .
# G: a young man putting on a pair of scissors .
# G: a woman using her phone to the camera .
# G: a large group of people and a man in a fenced area in the traffic
# G: the stuffed animal in the patterned of its enclosure .
# G: a street sign in a corner of person buildings
# G: two men are sitting on a table using laptops laptops .
# G: the blue jet is on the runway on a runway .
# G: a small girl with glasses and a banana bottle of wine
# G: a boy and woman double ready to drives at the same ball
# G: two tall animals stand near a building with a clock .
# G: a group of people with luggage bags and bags for luggage .
# G: a soccer player playing soccer in the grass .
# G: a some standing over a skateboard in front of another
# G: a white kitchen has been cutting a pizza .
# G: enjoying of scissors sitting on a white counter in the bathroom .
# G: a hot dog on the side of its cup open .
# G: two close up of a table in a vase of many flowers
# G: a background light sits on top of a skateboard .
# G: a group of wine sitting on top of a table .
# G: a man is standing in the park of the beach .
# G: a couple of people pose at the same eat
# G: a man is looking over a prepares of a banana
# G: a some putting a pizza on his cell phone .
# G: a young boy standing on a field holding a ski slope .
# G: a some that is holding a bat in front of a fence .
# G: a white bowl sitting on top of person green vegetables .
# G: a red train with graffiti coming into a station
# G: a man stands and two women are on the beach .
# G: a bathroom with white separate and sink and a toilet .
# G: a young man in a bed using a bear computer
# G: a dog playing a game of frisbee with a dog and dog
# G: a small dog that is sitting on a bench .
# G: a man flying over a kite on the ground .
# G: a group of people are holding up a teddy laptop .
# G: a woman sitting down next to a teddy laptop .
# G: a man standing in front of two people .
# G: a woman standing next to a banana tree at the table .
# G: a red background light with trees on the traffic .
# G: a young man with his cell phone is talking on a phone
# G: a boy holding a kite in the air over a sandy beach .
# G: two lettuce of a bear with a bear and a cat on a table .
# G: a man and woman looking at a giraffe through a banana .
# G: a skier going on a snowy hill with a big white traffic
# G: a man riding a horse in a green field .
# G: a man sits in front of a banana .
# G: a woman baking her cellphone while holding a remote .
# G: a man is playing a game in his mouth .
# G: a man on top of a surfboard of skis on a cement cluttered .
# G: a bathroom with white separate and a sink on the floor .
# G: two microphone a bathroom with a toilet and shower
# G: a large passenger jet flies in a underneath sky
# G: a street full of background lights next to the street .
# G: the dog is looking at the camera the camera .
# G: a close up of a banana on a drinking with a banana .
# G: a white toilet bowl full of carrots , and white paper .
# G: a city street scene with no parking lot .
# G: a young man that is looking up at the camera
# G: a group of people flying a kite together .
# G: a black and white photo of shown holding a camera
# G: a teddy laptop sitting on a table next to a window sill .

# %%
model.linear_interpolate(checkpoint, num_samples=10)
# Out:
# INFO:tensorflow:Restoring parameters from models/lyrics-50.ckpt
#
# G: some sitting in front of a bear with a bag of a banana
# G: some sitting in front of a large box of donuts on the table
# G: a man sitting on a table in front of a car
# G: a man sitting on a bench in front of a car
# G: a man on top of a motorcycle in front of a building
# G: a man on top of a motorcycle parked at the grass
# G: a man on a bike on a bike of person grass
# G: a couple of people on a bike down a large building
# G: a couple of horses on a field of an old building
# G: a couple of horses on a field of grass together
#
# G: a man in a suit and tie sitting on smiling .
# G: a man sits in a chair while talking on phone .
# G: a man sits in a chair talking on his phone .
# G: a man sits on a bench talking in his plane .
# G: a man sits on a bench talking in his plane .
# G: a man sits on a bench talking on his cell phone .
# G: a man is holding a skateboard on the cement filled .
# G: a white cat sits on a cluttered in the play traffic .
# G: a white building has a red on the wooden filled .
# G: a white building has a red on the wooden filled .
#
# G: a man with a sandwich , and a woman cut out in the traffic .
# G: a woman with a red streets tie in a black shirt at her .
# G: a woman with a red streets tie in a black traffic at night .
# G: a zebra through a tree in a fenced area looking at the camera .
# G: a zebra grazing with a baby elephant in the middle of trees .
# G: a zebra grazing with a baby elephant in front of the grass .
# G: a zebra walking with a baby elephant in front of trees .
# G: a zebra walking with a herd of elephants walking eating the grass .
# G: a zebra elephant with a herd of elephants walking eating the grass .
# G: a elephant walking with a herd of elephants and an elephant .
#
# G: a man wearing black shorts and a black shirt and white cat .
# G: a man holding a skateboard and a woman standing near red .
# G: a man holding a skateboard in a black and white photo .
# G: a man holding a skateboard in a black and white photo .
# G: a man holding a skateboard in a black and white photo .
# G: a man holding a skateboard in a black and white photo .
# G: a man riding a bike and a woman standing near two horses .
# G: a man riding a bike and a woman standing near two horses .
# G: a man riding a bike with a dog and woman walking .
# G: a man riding a bike with a woman standing near her .
#
# G: two small bears in the middle of an open area .
# G: two small dogs in the decorated on the same day .
# G: two small dogs in the middle of a large bathroom .
# G: a large cat sitting in the middle of the water .
# G: a large bed sitting in the middle of the water .
# G: a large bed sitting in the middle of a meat room .
# G: a large bed sitting on a drinking next to each other .
# G: a large bed sitting on a wooden floor with a window .
# G: a couple of chairs sitting on a bed with a book
# G: a couple of chairs sitting on a bed next to each other
#
# G: person people are holding a large bunch of luggage .
# G: person people are standing on a filled of an airplane .
# G: person people are sitting on a bench in the snow .
# G: two trains are sitting on a track in the yard .
# G: two trains are sitting on a track in the yard
# G: two trains sit wild a train on the tracks
# G: two trains parked along a train on the tracks together
# G: two trains parked along a train on a train station
# G: two animals eaten along a train on a train station
# G: two animals eaten along a bench at a train station
#
# G: a man in black shirt sitting on a bench with his dog .
# G: a man in black shirt sitting on a bench with his dog .
# G: a black and white cat sitting in front of the window .
# G: a black dog in the back of a car parked outside
# G: a black cat in the kitchen looking at the camera
# G: a black cat in the kitchen staring at the camera
# G: a close up of a some in a living room
# G: a close up of a some in a living room
# G: a close up of a some in a living room
# G: a close up of a some in a living room
#
# G: a some standing near a fence with a horse in the traffic .
# G: a some standing near a fence with a horse in the traffic .
# G: a some standing near a fence and trees in the traffic .
# G: a man standing next to a horse picnic in the grass .
# G: a man standing next to a horse picnic in the grass .
# G: a man standing next to a horse picnic in the grass .
# G: a couple of elephants standing with a tree in the traffic .
# G: a couple of elephants standing and walking in a tall building .
# G: a couple of elephants standing and walking in a tall building .
# G: a couple of elephants standing and walking in a tall building .
#
# G: two men in suits at a table with their meal
# G: two men dark in a game of tennis players dark
# G: two men dark in a game of tennis players dark
# G: two men dark in a game of tennis rack games .
# G: a man playing in a game of tennis rack tennis .
# G: a man skateboarding on a motorcycle during the day eat .
# G: a man skateboarding a bike down the street during the day .
# G: a man we a bike down a street during front .
# G: a street sign showing the intersection of a parking meter .
# G: a street scene of a street sign on a city street .
#
# G: a parking meter sits by a building with a building .
# G: a parking meter sits by a building with a lot .
# G: a small bus parked on a sidewalk with a building .
# G: a small bus parked on a sidewalk with a lot .
# G: a small kid sits on a skateboard with a skateboard .
# G: a small group of people on a skateboard with a filled .
# G: a close up of a some in front of a television .
# G: a close up of a some with scissors on a skateboard .
# G: a close up of a some with scissors on a skateboard .
# G: a close up of a some with scissors on a skateboard .

# %%
model.get_neighbourhood(checkpoint, x_test[200::220], temp = 3.0)
# Out:
# INFO:tensorflow:Restoring parameters from models/lyrics-50.ckpt
#
# A: a white toilet next to a tub and a sink inside of a bathroom .
# G: a woman sleeping next to a dog and a dog on a bed .
# G: two of background lights on a city street in front of a building .
# G: a small white toilet next to a sink next to a toilet .
# G: a some with scissors and scissors cutting a white toothbrush in a bathroom .
# G: two pizzas on a table that is in a bowl of a coffee cup .
# G: a bear is sitting under a table , a cup of coffee .
# G: a cat looking up open a window and a window and a window .
# G: a white boat next to a body of water with a body of water .
# G: a glass window with a sink sitting on top of a window .
# G: a sandwich sitting next to a plate of food next to the table .
#
# A: a pair of zebras standing in a dry brush field .
# G: a couple of giraffe standing in a large field .
# G: a black bird is in the sky on a green slope .
# G: a herd of elephants standing together in a river .
# G: a man is standing in a snow covered ski area .
# G: a man in a black on a brown horse picnic carriage .
# G: a enjoying of food served on a white plate .
# G: a close up of a some with a little girl .
# G: a man on skis and other a jump .
# G: person people are watching a large big big big kite
# G: large group of teddy laptop sitting on a motorcycle inside .
#
# A: a platter of a number of different foods
# G: bathroom that has a toilet and sink .
# G: a bowl wall with a cup of wine
# G: a display of a stuffed animal by display .
# G: the close up of a bird in water
# G: a enjoying of a bowl of donuts
# G: a close up image of a small box is
# G: a white sink a paper and two pieces
# G: a couple of a hand inside a lot
# G: a herd of giraffe standing next to side
# G: a enjoying of chocolate is cutting a cake .
#
# A: computer monitor and laptop on desk with other electronic equipment .
# G: the computer with a phone next to the side .
# G: a cat looking at a computer and computer monitor mirror .
# G: two cell phones on top of an open desk counter .
# G: a computer with no cell phone and is being messy
# G: a desk on top of a desk made computer
# G: a bed next to two rock and other teddy bears .
# G: a woman on a tennis court with her cell phone .
# G: two motorcycles parked next to a parking lot standing together .
# G: a cat in a bed made to person computer monitors .
# G: two people getting are talking while they are talking together .
#
# A: a giraffe laying on top of the ground .
# G: the toilet has a black and white toilet seat seat
# G: a blue motorcycle in black top of the dirt ground .
# G: a close up of giraffe in the snow .
# G: a man sitting on a table reading a phone .
# G: a man laying on top of the ground
# G: a dog sits on top of paper .
# G: a zebra grazing in a fenced in its mouth .
# G: a bowl wall with carrots next to each other .
# G: a sandwich is lemon and parade
# G: a baby bird with birds on the grass
#
# A: a wood stove with the door open revealing the fire inside .
# G: a fire hydrant with a large crowd of its doors
# G: a woman is playing with a game of hot dogs
# G: a who decker with a broken refrigerator on the floor .
# G: a truck wall with red and white truck with parked cars .
# G: sandwiches ties , carrots , broccoli and an oven oven .
# G: a enjoying of scissors covered with scissors in the plane .
# G: the kitchen is a white counter top and the table
# G: a group of cows and other animals at the same eat together .
# G: a parking meter with a car parked next to the other side .
# G: an older man is in fur , while at an low
#
# A: a large room with many stacks of suitcases .
# G: a small fire hydrant and grazing in grass .
# G: a man with glasses is posing for plain .
# G: a kitchen with many plates of food with vegetables .
# G: an old bed and a white keyboard and keyboard
# G: a park bench with wooden smoke and wooden floor
# G: an elephant is holding an umbrella next to toddler .
# G: a couple of white dogs and a dog
# G: a young woman with a picture of something .
# G: a couple of birds on grass on grass .
# G: a blue and white fire hydrant and white .
#
# A: there is a lot of food to be eaten on this plate .
# G: lots of pizza next to a pan on top of .
# G: a couple of men standing next to a couple of horses
# G: there is a boy is playing a game of soccer .
# G: shown is in a kitchen preparing to cut into the oven
# G: this is a bird in a blue vase is in a tree .
# G: a plate of food is someone with a home and vegetables .
# G: the meal of a plate of food in the restaurant table
# G: the batter is wearing a green and white bowl of sandwiches vegetables is spoon .
# G: a bunch of food is sitting next to person of green vegetables
# G: a couple of food from a plate of food at person food
#
# A: a slice of pizza with vegetables sitting on a plate near a drink .
# G: a table is full of donuts and two wine and person wine .
# G: a cutting board with a knife , with a onto ,
# G: a cutting board and two pieces of pizza on top of them .
# G: a man with tennis racket next to a woman with a racquet .
# G: a piece of cake with a baby sandwich sandwich in the traffic
# G: a bunch of small and wine on top of a table
# G: a blue and white plate that is sitting on top of counter .
# G: a close up view of kitchen with wooden counter top of a kitchen counter .
# G: a plate of food that are sitting in a bowl with person food .
# G: a pizza , cheese sitting on top of a plate with a pizza .
#
# A: a street sign prohibiting vehicles in front of a store .
# G: a stop sign showing people skiing at night .
# G: a stop sign on street signs and says a street
# G: a zebra standing next to tree structure into a tree .
# G: a baseball pitcher shaped like a tree apples in a tree .
# G: a green fire hydrant and green trees and a tree
# G: a bunch of food from a table near a restaurant .
# G: large stop sign hanging on top of a tree .
# G: a tall train traveling eating the side of a river .
# G: a red fire hydrant on top of a building .
# G: the red motorcycle stop sign with other motorcycles a stop .
#
# A: scissors , tape , needles , and a long strip of grey fabric are piled
# G:
# G: this is an image of an image of an image of water
# G: two little girl in a green chair is sitting on a table next to two
# G: two pizzas on one is sitting on a plate with two orange .
# G: sandwiches , and vegetables , banana , banana , and bananas and other stop sign
# G: a box with donuts on a red box with a banana box .
# G: a small bed with two pieces of luggage on a small white bag bag
# G: two slices and white donuts , one on top of paper and other items .
# G:
# G: a bride and baby dressed in bed with teddy bears in teddy bears .
#
# A: a white car is driving down a city street
# G: a large boat on a beach near a city
# G: a woman is preparing to fly a skateboard .
# G: a some is driving on the street .
# G: a large city street at night with a city street
# G: a young man is riding a skateboard riding a wave
# G: a red fire hydrant is near a city street .
# G: a motorcycle is parked outside a car parked outside
# G: a some is going out at an intersection stop sign
# G: a truck being arm out at a foot
# G: a tall building is stopped by a street
#
# A: a room with tables and laptops and a power point screen .
# G: clock in front of building is very large very large tower tower .
# G: a some wearing a black shirt and a black cat .
# G: woman wearing white shirt and tie holding food to time food .
# G: a kitchen area in a corner and a have day .
# G: street with one way up a street sign up a street sign
# G: a man and woman getting is using a cell phone .
# G: a kitchen that is someone in a kitchen counter is someone .
# G:
# G: a woman getting is playing video game with a video game .
# G: a window holding a light a yellow light colored window .
#
# A: a view of a rall brick building at night with a clock on it .
# G: a view of a clock tower by a window window .
# G: a couple of lights are someone with a cell phone on it .
# G: there are many wedding and the tower is in front of building and many different
# G: a group of people are waiting to the big pickle building with a big clock
# G: a group of people are at a park bench while on a sunny day .
# G: a view of a body of water with a body of water .
# G: a cell phone with a cell phone with a phone with an office .
# G: a view of a city street lights lights with lights lights .
# G: a view of a street sign showing a clock tower , night , street lights
# G: two large black giraffes of a large group of giraffes in front of trees .
#
# A: a brown dog running across a sandy clearing .
# G: a woman riding skis and a snow covered hillside .
# G: two zebras grazing together and grazing together grazing .
# G: a man riding a horse across a field .
# G: a yellow fire hydrant sits in a blue sky .
# G: a large dog standing near a large elephant .
# G: a horse is grazing in a dirt field
# G: a man riding small horse in green grass .
# G: a man riding a skateboard in a big city .
# G: an older woman taking a picture of a prepares .
# G: a young man standing beside a white filled .
#
# A: clean lines and minimal , lightweight furniture are the decor in this living space .
# G: two signs that are a stop sign that says stop sign .
# G: the cell phone , mirror , mirror , mirror , window and a mirror .
# G:
# G: a clock tower on top of a wooden table , a clock and other .
# G: two plates of food in a large bowl of food , including and vegetables .
# G: a red , red , red and red stop sign at the night .
# G: this image of scissors that is cutting into a birthday cake that is cutting board
# G: black and white car in front of a car window looking out .
# G: a living room with wood smoke and a tv in traffic
# G: street signs and cars and bread and bread and cars parked along .
#
# A: a picture of a toy elephant on a table .
# G: an image of a man is talking on a phone .
# G: a man is holding a pizza in a restaurant .
# G: a picture of a some is looking inside a mirror .
# G: this picture of a clock tower on a building .
# G: this looks like a black laptop wearing a black jacket .
# G: a group of small pieces of a banana .
# G: a bunch of animals that are on person hay .
# G: a pair of scissors using an office .
# G: a group of people are gathered at a park .
# G: a picture of a small cat that is sitting outside .
#
# A: a pitch being thrown to home plate during a baseball game .
# G: a fire hydrant is someone from the corner of the sidewalk .
# G: a baseball player that is on a plate of tennis .
# G: two pizzas are on a plate on top of a wooden table
# G: a man double ready to hit a ball game of baseball .
# G: a large white plate of food inside of a large green field .
# G: a batter hitting a baseball game with a baseball bat
# G: a tennis player is in the air to a ball
# G: a little girl is up up to hit a plate
# G: two pizzas are preparing to gathers food on a tennis court
# G: the table is full of food items of an oven
#
# A: this outdated bathroom really could use some updating .
# G: this bathroom is very large white bathroom .
# G: person animals out the trees in the traffic
# G: a male skateboarder is looking into the air background light .
# G: a white sink is sitting over a case tub .
# G: an old toilet is lone up .
# G: the large pizza topped with cheese pizza served .
# G: a white refrigerator showing two different appliances appliances .
# G:
# G: the large cat is looking from its mouth .
# G: a white bathroom sink and a white toilet
#
# A: a vase with flowers on a table
# G: a couple of person sort for a table
# G: a bowl with carrots on a table
# G: a black and white motorcycle with a
# G: a bus that is sitting by a building
# G: a some on a surfboard on a beach .
# G: a small vase and yellow flowers in the vase
# G: a toilet on top of a filled
# G: a vase with flowers on a table .
# G: a pizza that is sitting on a table
# G: a vase that is on a underneath day
#
# A: a bride and a groom feeding cake to each other .
# G: a close up of a sandwich next to a coffee tiny .
# G: the cake that are sitting on the table with their cake .
# G: a plate holding a sandwich sandwich and person fries
# G: there are many birds that are standing above person water together .
# G: a couple of sheep that are next to an open field
# G: a woman and a table , table and person food .
# G: an old woman with a large sandwich at the table .
# G: a couple of women with a knife cutting a cake .
# G: a couple of flowers in a vase of wooden flowers .
# G: a some that is playing frisbee along the beach .
#
# A: people are waiting at the airport for their plane .
# G: man taking a picture with a skateboard in its mouth .
# G: a some is rest on a skateboard park covered area
# G: a man is on the side of a refrigerator .
# G:
# G: people looking down at night with no parking lights .
# G: a man double ready to beverage person large small dogs .
# G: people are standing on their skis down the street .
# G: a man is on top of person colorful water .
# G: a bus is at an intersection at an airport intersection .
# G: a man stands in a large area with many motorcycles .
#
# A: two boys with a man in a room smiling for the camera .
# G: a some and a woman in a black shirt and tie .
# G: a man and woman dark video game in room in the room .
# G: the man and a woman dark a game with remote liquid
# G: a some holding a bear next to a bear in front
# G: woman in a living room with a couch of tv .
# G: a man in a black shirt and tie and person glasses .
# G: two women in a kitchen holding a wii while holding .
# G: the people and a man getting is standing near the ocean .
# G: a some in a chair playing a game of person people
# G: a boy in a kitchen with a cell phone above the screen .
#
# A: five adult giraffes are moving through very tall brush .
# G: a some is standing near two elephants are standing together .
# G: two women are talking while playing tennis together .
# G: the some is posing for the picture baseball .
# G: the bowl of food next to two other food .
# G: the some is using a snow board up up .
# G: person people are skiing down a big elephants together .
# G: the dog is wearing its mouth open outside .
# G: a banana looking out looking out two hair .
# G: a little boy is playing with a big yellow frisbee
# G: two young men standing and holding up baseball .
#
# A: a man helping his friend knot his tie outside
# G: a man dressed in black jacket and tie talking
# G: a baby sitting down looking up with his banana
# G: the man is sitting on the table reading
# G: man looking at the camera next to a clock .
# G: a group of young people sitting together together
# G: a man wearing a black and white shirt through
# G: some about to take off the rail out train station
# G: a man standing near a pair of snow skis
# G: group of men closeup baseball during at night .
# G: an woman sitting on a small brown couch
#
# A: a city bus with hard blue double seats
# G: a some riding a horse with a big elephant
# G: person big yellow motorcycles that are
# G: a man riding in the air against luggage
# G: a red and white bus on red background
# G: a young boy in a yellow with yellow skateboard
# G: two boats in a large open water .
# G: a man walking under a large green umbrella .
# G: a yellow motorcycle parked on a city street
# G: the zebra is grazing with trees and person trees
# G: a bus stopped at a who decker bus station
#
# A: a man is making a sandwich on a table
# G: a man is sitting at a table through a pizza
# G: two women are sitting on a bed on a bed .
# G: a man that is sitting on a bear
# G: two different donuts are being cut in their face .
# G: a couple of women are sitting next to person coffee .
# G: a man cutting a cake at a table preparing food
# G: a boy is cooking on a bear and keyboard .
# G: a couple of people are sitting near a table .
# G: a woman is through a sandwich in a vase .
# G: this is a cutting board on a cutting board .
#
# A: an old building with a balcony on it and unique windows
# G: a table near a building and a country and phone .
# G: two men looking at an open pizza with a large pizza together .
# G: an old , empty beach sitting on the beach wall with tall buildings .
# G: the light is on the corner of a street with lights
# G: street signs on a pole on top of street .
# G: an image of a bench with a bench and empty fire hydrant outside
# G: a black and white photo of a bathroom with white walls
# G: an old and white photo of a clock at a building
# G: a man with a horse and a horse down the road
# G: two street signs with a street sign sitting and trees
#
# A: this is an image of an internet cafe .
# G: this kitchen is an image above an oven .
# G: two men cross a hill during the day .
# G:
# G: a young boy is doing a trick outside .
# G: a enjoying is cutting a number an oven .
# G: a small bathroom is someone to small bathroom .
# G: is a male and woman getting is playing tennis .
# G: a group of people in an open refrigerator cooking .
# G: the view eating the front of an open airplane .
# G: a bear that is under an open book .
#
# A: a baseball trading car depicting a pitcher for the steam monkeys minor league baseball team
# G: a some using a banana with a banana on his back polar plane .
# G: a man riding a motorcycle picnic carriage with an elephant with his trunk .
# G: a couple of men are playing with a game of baseball game are playing baseball
# G: a some is about to swing his racket is ready to swing his bat
# G: a little girl taking a see of pizza at a little girl .
# G: a female tennis player playing tennis game with a tennis racquet other
# G: a woman on a baseball field throwing a dress into a large dress area .
# G: a large elephant in green field next to trees and person tall trees
# G: a woman cutting a banana banana with a banana tree trunk .
# G: an older female tennis player with an cooked racket , playing with his racket is
#
# A: a black parking meter with time left on it .
# G: a very dirty baseball player swinging on a tennis court .
# G: the truck parked on a white plate in the parking lot .
# G: a white kitchen counter and a white and white counter top .
# G: an airplane parked over a small , old fire hydrant .
# G: a baseball player with bat and cooked on a green plate .
# G: a very clean kitchen counter with a stainless steel oven oven .
# G: a bunch of people standing on top of field .
# G: a woman that is preparing to dark on tennis .
# G: a very big kitchen wall with lots of food
# G: a tennis player jumping in the air after the ball .
#
# A: a girl sits down and eats a donut with some tables and chairs in the
# G: a table is full with a large window and a window and person food items
# G: a woman sitting at a table with a bear in front of it .
# G: a man sitting down a chair with a teddy laptop and a woman in a
# G: a woman sits on a toilet seat with a dog in a plane on her
# G: a small meal of pizza on top of a table with a large pizza .
# G: the woman looking out the window of a room with many people and two people
# G: a some looking at a plate with person food and person food on it
# G: a little girl sitting in her chair while holding an umbrella while sitting on a
# G: an elephant is sitting on a chair while another cat is sitting down .
# G: a group of people are sitting on benches with stuffed animals and a woman is
#
# A: a girl is playing softball on a dirt field .
# G: a yellow fire truck is in a parking lot .
# G: a some is standing up on a baseball field .
# G: a zebra that is walking on a grass field .
# G: a little boy sits on a bed in a bedroom .
# G: a sandwich covered with broccoli and a broccoli sauce .
# G: two people are dressed in snow on the snow
# G: a some is walking sofa on a sandy beach .
# G: a young boy is jumping on a snow board .
# G: a young boy is preparing to hit a baseball bat
# G: a woman that is standing in a parking lot .
#
# A: a zebra looks at another zebra across the pen
# G: an airplane flies lawn in the sky for the camera
# G: a little girl with a child that is standing outside
# G: two trains ride on display in front of cars .
# G: a woman on the ground holds a giraffe
# G: a stop sign for a stop sign outside .
# G: a woman looks at her giraffe to time the grass .
# G: the zebra zebra on the grass next to the grass
# G: a man takes a picture to an airplane
# G: a some looking at the camera while the water out
# G: a toy people in horses are pulling a wet
#
# A: a flower vase with pink flower inside of it .
# G: a baby elephant with baby elephant swimming in the water .
# G: a vase sitting on a table with a plate
# G: a zebra that has two zebras animals in it .
# G: two white and white bowls with different happy of food .
# G: a vase and a yellow vase inside a window .
# G: a glass of window in a room with window .
# G: a small elephant that has a couple of elephants
# G: a large vase with flowers sitting on top .
# G: banana in a vase sitting on top of an apple .
# G: a display bath is on display and person flowers .
#
# A: a bangladesh airlines num is taxiing down a runway .
# G: the big computer keyboard is being arm by a keyboard
# G: two red who decker bread are on a street
# G: a street sign with a car parked outside it
# G: a very nice looking like fruit for a banana
# G: a small group is looking at a camera .
# G: a toy people are lined up in a street
# G: a large building of a street sign a building
# G: a white refrigerator goat looking out person window
# G: an old fashioned train is parked in a station .
# G: the train is stopped at night at the train station .
#
# A: the man bends down on the skate board .
# G: a woman standing on top of a surfboard .
# G: a man populated on top of the beach against surfboard .
# G: man is using a video game on his skateboard .
# G: a woman is jumping on a skateboard board jumping .
# G: a man standing outside on the skateboard skateboard .
# G:
# G: the man jumping off the skateboard
# G: the skateboarder taking a picture in his plane .
# G: a some riding a skateboard on his skateboard .
# G: a man looking at a phone and tie .
#
# A: a dog laying on top of a flowered pillow .
# G: a some in a small kitchen on a wooden floor .
# G: a boat sitting on top of a sandy beach .
# G: a some on a skateboard with a tennis racket
# G: two sheep and a wooden fence and a train .
# G: dog standing on top of side in a parking lot .
# G: a couple of horses that are on a small hill
# G: a dog laying in front of a bear computer .
# G: people waiting to wooded a hand in the air
# G: a man with white walls on a white floor .
# G: a man against a skateboard wet of luggage .
#
# A: horses graze freely in the open field together
# G: a dog is standing in an open air
# G: women holding a baby at their baby together
# G: there are two horses that are being arm together .
# G: there are two trains traveling down a track
# G: a man walks down an old train track .
# G: a horse grazing in green grass covered pasture
# G: giraffes for a zebra person very large grass
# G: some in a helmet riding next to two other
# G: a man doing a kite in the sky
# G: cows grazing in the dirt road together
#
# A: view of kitchen sink full of dishes , counter around and closed cabinets below the
# G:
# G: a kitchen is in a kitchen area , a small , counter ,
# G: a picture of bathroom with a toilet paper on the top of it .
# G: lots of street signs on a city street near a building and lights .
# G: kitchen sink , a kitchen sink , a kitchen , oven , oven a kitchen
# G: view of bathroom area , sink , toilet , sink , and toilet ,
# G: kitchen with wood cabinets , cabinets , and a toilet ,
# G: view of cat sitting down in a car with a some standing on a filled
# G: the cat with a bear on the side of the side by a keyboard
# G: the view of bathroom with white walls and white walls and white walls is painted
#
# A: a close up of a dog riding a surf board
# G: a sink and a toilet and a toy center
# G: a group of people standing next to a little nicely
# G: a group of rock are sitting on a bed .
# G: an adult of a some jumping in a surf board
# G: a close up image of a some riding a skateboard
# G: a close up of a some riding a wave
# G: a black photo of a car parked outside parked outside
# G: a picture of a some sitting on a skateboard floor .
# G: a close up of a some riding a skateboard
# G: an adult couple standing on an open window sill
#
# A: two zebras that are standing in the dirt .
# G: a zebra in green trees in the traffic .
# G: person people that are standing in the snow
# G: person zebras on the dirt are by a field .
# G: a zebra through a tree apples on its side .
# G: black and white photo of giraffe on a field
# G: two horses in street near buildings near buildings .
# G: a truck that is parked in a dirt .
# G: a couple of giraffes that are standing together .
# G:
# G: a large field with a large white umbrella
#
# A: a group of people sitting around two tables .
# G: a bunch of people with different different trucks .
# G: a group of people standing near an umbrella .
# G: a man standing in front of two motorcycles
# G: a group of people being around in their face
# G: two horses are parked next to a train station .
# G: a enjoying of a some sitting down the ground .
# G: very advertisement display of bears and very dirty display .
# G: a group of people playing a game together
# G: a toy people are cutting up together together .
# G: a woman sits down using a bear computer keyboard .
#
# A: granite counter tops in a new white kitchen
# G: a train yard in the side by side
# G: is a computer keyboard in a blue computer .
# G:
# G: red fire hydrant that is in play colored snowboarding
# G: in a sandwich in a white plastic nearby .
# G: person fruits are in front of a big kitchen counter
# G: a hand taking person people with many lunch
# G: the front of a clean modern bathroom
# G: person kitchen cabinets with a large white refrigerator
# G: person people looking at an intersection taking a picture
#
# A: a blue , white and grey train passing by river and houses .
# G: a train that is near a train station and the tracks .
# G: a large elephant in black and white bears walking by trees
# G: a large , old , old , and water , and water .
# G: a black and white cat laying on a surfboard on the tracks
# G: a blue , yellow , yellow train is by the train station .
# G: train tracks and tracks near a train station near train tracks .
# G: sign and sign at the street sign that says stop sign .
# G: brown and white train traveling under a river wall by a river .
# G: a black cat and white cat looking up from a window
# G: a little boy in black shirt is looking out to him .
#
# A: a bus and a truck are pictured driving on a street .
# G: a train that is in a train that is in a field .
# G: a bus in a city street with cars on the street
# G: a beach on a city street with a clock on a beach
# G: a skateboarder on a skateboard being arm into an airport parking area .
# G: shallow are in the air preparing to take off .
# G: a large building with a lot of cars on the side .
# G: a pile of luggage on a wooden desk in an office
# G: a truck on a road with a tree on a street .
# G: a kitchen with stainless and vegetables is in a pan .
# G: people getting are doing a trick on a city street .
#
# A: a room with red and black chairs , and a tv on the floor .
# G: bowl of hair with hair and wine in a bowl wall with fruit .
# G: a filled and white filled and a wooden floor and a filled .
# G: a some playing tennis , walking and walking eating the street ,
# G: woman with white desktop in a living room with a television screen .
# G: white toilet sitting in bathroom with sink and toilet paper covered in bathroom .
# G: a toilet with a blue plate with a white plate on a table .
# G: a kitchen that has two cabinets and a window in the play traffic .
# G: a white and white toilet and a white toilet and other flowers and other .
# G: a train station with its doors in the middle of the middle .
# G: a kitchen counter top , oven and oven on top of a counter .
#
# A: a busy dirt street with people and a brown cow
# G: a street is standing next to a busy street light
# G: two yellow fire hydrant are covered in the dirt together .
# G: a white horse picnic carriage on a dirt road .
# G: a small black and white photo lap a horse
# G: a woman standing with their skis of a parked truck .
# G: looking blue and white bird looking at the camera .
# G: a big blue truck parked next to a fire hydrant .
# G: a red covered mountain on top next to a forest .
# G: a tall building is in a city with a street
# G: a building has person green flowers in front of tall grass
#
# A: a cat is laying on top of a closed laptop .
# G: dog is lying on the bench while a few few .
# G: a couple of women are sitting on person grass .
# G: a man is looking out on a bear computer .
# G: a cat sits on a keyboard with a remote skateboards .
# G: a couple of women that are on a brown couch .
# G: a knife is sitting on top of a counter top .
# G: a man is holding a pizza with a cell phone .
# G: a some is using his cellphone on his cell phone .
# G: a large giraffe sitting on top of a wooden table .
# G: a some is cooking with hot hot dogs is cooking .
#
# A: a bunch of bats flying over a parking lot .
# G: a small dog laying on a white toilet
# G: a couple of planes flying over a parking lot
# G:
# G: a bird above a metal fence in a fenced area
# G: a couple of kites flying in a large field .
# G: a pair of broccoli broccoli on top of a plate .
# G: a bunch of kites being travels over a parking meter .
# G: a park area of snow covered beach covered area .
# G: a bunch of kites flying over a fire hydrant
# G: a picture of a small road on an intersection street .
#
# A: a stop sign in front of a group of houses
# G: person bananas in a blue and white box is sitting up .
# G: a stop sign in a fenced of an leading area area .
# G: a motorcycle on a street with a half of motorcycle
# G: a blue motorcycle a blue and white motorcycle blue sign .
# G: a train in a track in a dirt and track
# G: the sign in the green , green , light and sky
# G: a small bed , made bed made from open window .
# G: a passenger train in train that is going down .
# G: two horses are in front of a red and white fire hydrant
# G: a red and white train sits on top of a train station .
#
# A: a woman sitting at a table in front of a cake with lit candles .
# G: a man holding black and white teddy laptop sitting next to a white teddy laptop
# G: a woman sits on a table with a bear and bottles .
# G: people standing behind a table in a room with a lit potted .
# G: the man posing for a picture of a baseball with his bat .
# G: two people sitting in the table in the middle of a birthday cake .
# G: an airplane sitting under an umbrella , a large , and an umbrella .
# G: a large building in a city street with a clock tower and trees .
# G: a woman poses for two people at a table on an low .
# G: a some using a cell phone to a man on his phone .
# G: two giraffes stand in the middle of a tree with other people stand .
#
# A: a cat lying on a television displaying a fish .
# G: a tennis player is at a plate with food .
# G: cat sitting on a white refrigerator and black refrigerator .
# G: two dogs dark with a dog and a dog
# G: a bunch of flowers next to a big window .
# G: a bear computer on a television on the sidewalk .
# G: a pizza sitting on a box on a table .
# G: a man standing over a woman holding a pizza .
# G: people dressed in costume , and a hotel made bed .
# G: a close up of a cat on a bed
# G: a bed sits on a bed with a bed .
#
# A: a woman and horse look each other in the eyes .
# G: group of people with surf nintendo standing in the beach .
# G: a hot dog and a dog in the soccer ball .
# G: a man and a woman in a boat in an ocean .
# G: a woman and woman holding two dogs in the grass .
# G: a blue and white bird standing in the snow .
# G: the hot dogs and one is wearing lid and a bag
# G: two women getting are riding their horses in the dirt .
# G: a baby in pink sitting outside in bed
# G: a large and white bench next to two other wooden .
# G: a woman and two dogs looking in a boat .
#
# A: an elephant is walking in a ring with trainers .
# G: two women standing in an open area that are standing together together .
# G: a small child is sitting in between chairs .
# G: the airplane is in the sky covered in snow .
# G: two zebra are standing in a field by person trees .
# G: the some rides a surfboard along with people .
# G: the view of a bus stop light with people .
# G: a beach is in a city pool by
# G: the city bus parked in the rain with parked outside .
# G: a field covered with a green field with trees
# G: a woman standing in the train station with luggage
#
# A: a young woman standing next to another young woman .
# G: two young women sit outside an old video game .
# G: the black cat is standing behind her black car .
# G: a woman standing next to her through pizza .
# G: two young men standing next to a refrigerator .
# G: a man with a white shirt standing clear his skateboard .
# G: a woman in black shirt holding a tennis racquet racquet .
# G: two young women riding horses across an open .
# G: two young woman is laying in the bathroom sink
# G: a young man standing next to two women .
# G: a white toilet sitting next to person brown bears
#
# A: a male in dark pants and a red tie .
# G: a man at a tennis ball during the day .
# G: man in white shirt and tie with a tie
# G: a small girl in a cutting board cutting .
# G: a male pizza on his white plate serving .
# G: a young man on a cutting board is standing
# G: a kitchen has been sand for a among tree
# G: a woman in a red shirt and a swing
# G: a surfer in blue shirt is brushing a bathroom .
# G: a man on a boat and person water .
# G: a woman in black shirt and tie a tie
#
# A: a desk with a keyboard next to a laptop
# G: a woman wearing a black and white train station
# G: a sandwich sitting on a table next to a plate .
# G: bedroom with a bear and a glass window .
# G: a cat sleeping in a chair in a room
# G: a box has a small sandwich next to it
# G: a man wearing a teddy laptop reading a book
# G: pizza and pizza sitting on top next to a pizza .
# G: street sign in a street wall with background light .
# G: a couple of stuffed animals sitting next to a table .
# G: a train that is in front of a train .
#
# A: a baseball player in a red and blue shirt with a baseball bat
# G: a baseball player that is swinging a bat behind a ball
# G: a man walking on a baseball field by person tall trees
# G: a black and white photo of a green banana tree a green sign .
# G: a row of horses that are in the grass by a beach .
# G: a man in a green field holding a bat and a baseball bat .
# G: a small baseball game with a batter , with an adult baseball .
# G: a tree with a green apple and a tree on a wooden table .
# G: two people walking in a road with a motorcycle with two other cars .
# G: a man standing on a snowboard in snow with a snowboard
# G: a man in a white shirt and is holding a tennis racket
#
# A: two men standing in an office room .
# G: two people sitting around a wooden bench
# G: a man is standing in an cats area .
# G: two men talking in an office office area .
# G: two men sitting in their laptops motor .
# G: two elephants sitting inside of a box .
# G: a picture of a television in a mirror .
# G: two men dark an windsurfing cell phone .
# G:
# G: two rock in a room are using two rock .
# G: two large teddy bears sitting on their laptops together .

# %%
z_vecs = model.get_zvector(checkpoint, x_test)
z_vecs.shape # 100-d vectors
# Out:
# INFO:tensorflow:Restoring parameters from models/lyrics-50.ckpt
# (14200, 100)

# %%
utils.plot_2d(z_vecs, test_labels, method='tsne')
